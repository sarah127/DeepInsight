# %% [markdown]
# <a href="https://colab.research.google.com/github/sarah127/DeepInsight/blob/master/stylegan3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # StyleGAN3 from NVIDIA
#
# **Notes**
# * To see the original code from NVIDIA [Check here](https://github.com/NVlabs/stylegan3)
# * We are using a pretrained model and fine-tuning on top of it.
# * If you come across bugs please post them in [Discord](https://discord.com/invite/awREd7EtMA)
#
# ---
#
# If you find this notebook useful, consider signing up for my [Code Sprout Newsletter](https://codesprout.substack.com/welcome) or [Check my links](https://shyambv.bio.link/)
#
# Medium article related to it is mentioned []()

# %% [markdown]
# # Setup

# %%
# !pip install einops ninja gdown
# Out:
# Collecting einops
#   Downloading einops-0.8.0-py3-none-any.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.2/43.2 kB 990.5 kB/s eta 0:00:00
# Collecting ninja
#   Downloading ninja-1.11.1.1-py2.py3-none-manylinux1_x86_64.manylinux_2_5_x86_64.whl (307 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.2/307.2 kB 7.6 MB/s eta 0:00:00
# Requirement already satisfied: gdown in /usr/local/lib/python3.10/dist-packages (5.1.0)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from gdown) (3.15.4)
# Requirement already satisfied: requests[socks] in /usr/local/lib/python3.10/dist-packages (from gdown) (2.31.0)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from gdown) (4.66.4)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (2024.6.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /usr/local/lib/python3.10/dist-packages (from requests[socks]->gdown) (1.7.1)
# Installing collected packages: ninja, einops
# Successfully installed einops-0.8.0 ninja-1.11.1.1

# %%
# Connect Google Drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ---------------------------------------------------------------------------
# EOF                                       Traceback (most recent call last)
# <ipython-input-7-c08144af2d93> in <cell line: 3>()
#       1 # Connect Google Drive
#       2 from google.colab import drive
# ----> 3 drive.mount('/content/drive')
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in mount(mountpoint, force_remount, timeout_ms, readonly)
#      98 def mount(mountpoint, force_remount=False, timeout_ms=120000, readonly=False):
#      99   """Mount your Google Drive at the specified mountpoint path."""
# --> 100   return _mount(
#     101       mountpoint,
#     102       force_remount=force_remount,
#
# /usr/local/lib/python3.10/dist-packages/google/colab/drive.py in _mount(mountpoint, force_remount, timeout_ms, ephemeral, readonly)
#     176   )
#     177   d.sendline(f'unset HISTFILE; export PS1="{prompt}"')
# --> 178   d.expect(prompt)  # The new prompt.
#     179   drive_dir = _os.path.join(root_dir, 'opt/google/drive')
#     180   # Robustify to previously-running copies of drive. Don't only [pkill -9]
#
# /usr/local/lib/python3.10/dist-packages/pexpect/spawnbase.py in expect(self, pattern, timeout, searchwindowsize, async_, **kw)
#     352
#     353         compiled_pattern_list = self.compile_pattern_list(pattern)
# --> 354         return self.expect_list(compiled_pattern_list,
#     355                 timeout, searchwindowsize, async_)
#     356
#
# /usr/local/lib/python3.10/dist-packages/pexpect/spawnbase.py in expect_list(self, pattern_list, timeout, searchwindowsize, async_, **kw)
#     381             return expect_async(exp, timeout)
#     382         else:
# --> 383             return exp.expect_loop(timeout)
#     384
#     385     def expect_exact(self, pattern_list, timeout=-1, searchwindowsize=-1,
#
# /usr/local/lib/python3.10/dist-packages/pexpect/expect.py in expect_loop(self, timeout)
#     177                     timeout = end_time - time.time()
#     178         except EOF as e:
# --> 179             return self.eof(e)
#     180         except TIMEOUT as e:
#     181             return self.timeout(e)
#
# /usr/local/lib/python3.10/dist-packages/pexpect/expect.py in eof(self, err)
#     120             exc = EOF(msg)
#     121             exc.__cause__ = None # in Python 3.x we can use "raise exc from None"
# --> 122             raise exc
#     123
#     124     def timeout(self, err=None):
#
# EOF: End Of File (EOF).
# <pexpect.popen_spawn.PopenSpawn object at 0x7e888b009660>
# searcher: searcher_re:
#     0: re.compile('root@8b4ce40f287f-f98cf58ecc544e0c93587ce5626e23d1: ')

# %%
import os
if os.path.isdir('/content/drive/MyDrive/WIP/stylegan3/'):
    # %cd '/content/drive/MyDrive/WIP/stylegan3/'
else:
    # !git clone https://github.com/bvshyam/stylegan3.git /content/drive/MyDrive/WIP/stylegan3/
    # %cd '/content/drive/MyDrive/WIP/stylegan3/'
# Out:
# Cloning into '/content/drive/MyDrive/WIP/stylegan3'...
# remote: Enumerating objects: 193, done.
# remote: Total 193 (delta 0), reused 0 (delta 0), pack-reused 193
# Receiving objects: 100% (193/193), 4.17 MiB | 4.00 MiB/s, done.
# fatal: premature end of pack file, 19 bytes missing
# fatal: fetch-pack: invalid index-pack output
# [Errno 2] No such file or directory: '/content/drive/MyDrive/WIP/stylegan3/'
# /content

# %%
# !git clone https://github.com/bvshyam/stylegan3.git   /content/drive/MyDrive/WIP/stylegan3/
# %cd '/content/drive/MyDrive/WIP/stylegan3/'
# Out:
# Cloning into '/content/drive/MyDrive/WIP/stylegan3'...
# remote: Enumerating objects: 193, done.
# remote: Total 193 (delta 0), reused 0 (delta 0), pack-reused 193
# Receiving objects: 100% (193/193), 4.17 MiB | 6.85 MiB/s, done.
# Resolving deltas: 100% (88/88), done.
# /content/drive/MyDrive/WIP/stylegan3

# %% [markdown]
# If you wanted to download the current dataset execute below code

# %%
#!bash /content/drive/MyDrive/WIP/stargan-v2-download/download.sh afhq-dataset

# %% [markdown]
# # Custom Dataset

# %% [markdown]
# Execute the dataset_tool.py and provide the source and destination of the input dataset. Also mention the resolution required.
#
# Examples:
#
#
#
# ```
# python dataset_tool.py --source=~/downloads/afhqv2/train/cat --dest=~/datasets/afhqv2cat-512x512.zip
# python dataset_tool.py --source=~/downloads/afhqv2/train/dog --dest=~/datasets/afhqv2dog-512x512.zip
# python dataset_tool.py --source=~/downloads/afhqv2/train/wild --dest=~/datasets/afhqv2wild-512x512.zip
# ```

# %%
# !ls
# Out:
# avg_spectra.py	 dnnlib      environment.yml  gui_utils    metrics	training       viz
# calc_metrics.py  Dockerfile  gen_images.py    legacy.py    README.md	train.py
# dataset_tool.py  docs	     gen_video.py     LICENSE.txt  torch_utils	visualizer.py

# %%
# !gdown https://drive.google.com/u/0/uc?id=1aAJCZbXNHyraJ6Mi13dSbe7pTyfPXha0&export=download
# Out:
# Downloading...
# From (original): https://drive.google.com/u/0/uc?id=1aAJCZbXNHyraJ6Mi13dSbe7pTyfPXha0
# From (redirected): https://drive.google.com/uc?id=1aAJCZbXNHyraJ6Mi13dSbe7pTyfPXha0&confirm=t&uuid=be6495dd-9cb0-4fe1-8341-b7e103ca1dfb
# To: /content/drive/MyDrive/WIP/stylegan3/few-shot-image-datasets.zip
# 100% 913M/913M [00:24<00:00, 37.0MB/s]

# %%
# %%capture
# !unzip few-shot-image-datasets.zip
# !mv few-shot-images data

# %%
# !ls
# Out:
# avg_spectra.py	 dnnlib		  few-shot-image-datasets.zip  legacy.py    torch_utils    viz
# calc_metrics.py  Dockerfile	  gen_images.py		       LICENSE.txt  training
# data		 docs		  gen_video.py		       metrics	    train.py
# dataset_tool.py  environment.yml  gui_utils		       README.md    visualizer.py

# %%
# !python /content/drive/MyDrive/WIP/stylegan3/dataset_tool.py --source=/content/drive/MyDrive/WIP/stylegan3/data/art-painting --dest=/content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip --resolution='512x512'
# Out:
# 100% 1000/1000 [00:24<00:00, 40.96it/s]

# %%
#Unzip the transformed data if you wanted to verify
# !unzip /content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip -d /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped
# Out:
# Archive:  /content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000000.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000001.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000002.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000003.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000004.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000005.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000006.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000007.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000008.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000009.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000010.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000011.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000012.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000013.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000014.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000015.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000016.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000017.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000018.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000019.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000020.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000021.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000022.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000023.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000024.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000025.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000026.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000027.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000028.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000029.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000030.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000031.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000032.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000033.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000034.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000035.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000036.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000037.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000038.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000039.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000040.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000041.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000042.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000043.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000044.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000045.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000046.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000047.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000048.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000049.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000050.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000051.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000052.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000053.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000054.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000055.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000056.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000057.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000058.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000059.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000060.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000061.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000062.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000063.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000064.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000065.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000066.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000067.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000068.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000069.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000070.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000071.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000072.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000073.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000074.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000075.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000076.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000077.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000078.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000079.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000080.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000081.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000082.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000083.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000084.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000085.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000086.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000087.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000088.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000089.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000090.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000091.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000092.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000093.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000094.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000095.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000096.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000097.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000098.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000099.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000100.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000101.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000102.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000103.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000104.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000105.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000106.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000107.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000108.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000109.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000110.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000111.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000112.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000113.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000114.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000115.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000116.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000117.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000118.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000119.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000120.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000121.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000122.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000123.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000124.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000125.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000126.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000127.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000128.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000129.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000130.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000131.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000132.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000133.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000134.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000135.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000136.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000137.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000138.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000139.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000140.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000141.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000142.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000143.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000144.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000145.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000146.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000147.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000148.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000149.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000150.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000151.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000152.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000153.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000154.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000155.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000156.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000157.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000158.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000159.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000160.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000161.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000162.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000163.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000164.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000165.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000166.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000167.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000168.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000169.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000170.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000171.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000172.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000173.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000174.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000175.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000176.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000177.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000178.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000179.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000180.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000181.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000182.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000183.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000184.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000185.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000186.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000187.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000188.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000189.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000190.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000191.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000192.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000193.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000194.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000195.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000196.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000197.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000198.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000199.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000200.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000201.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000202.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000203.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000204.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000205.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000206.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000207.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000208.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000209.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000210.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000211.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000212.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000213.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000214.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000215.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000216.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000217.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000218.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000219.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000220.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000221.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000222.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000223.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000224.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000225.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000226.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000227.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000228.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000229.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000230.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000231.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000232.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000233.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000234.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000235.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000236.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000237.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000238.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000239.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000240.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000241.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000242.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000243.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000244.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000245.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000246.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000247.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000248.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000249.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000250.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000251.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000252.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000253.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000254.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000255.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000256.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000257.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000258.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000259.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000260.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000261.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000262.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000263.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000264.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000265.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000266.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000267.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000268.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000269.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000270.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000271.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000272.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000273.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000274.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000275.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000276.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000277.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000278.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000279.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000280.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000281.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000282.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000283.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000284.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000285.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000286.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000287.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000288.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000289.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000290.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000291.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000292.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000293.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000294.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000295.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000296.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000297.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000298.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000299.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000300.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000301.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000302.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000303.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000304.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000305.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000306.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000307.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000308.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000309.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000310.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000311.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000312.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000313.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000314.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000315.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000316.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000317.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000318.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000319.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000320.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000321.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000322.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000323.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000324.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000325.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000326.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000327.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000328.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000329.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000330.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000331.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000332.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000333.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000334.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000335.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000336.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000337.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000338.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000339.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000340.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000341.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000342.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000343.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000344.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000345.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000346.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000347.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000348.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000349.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000350.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000351.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000352.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000353.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000354.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000355.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000356.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000357.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000358.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000359.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000360.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000361.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000362.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000363.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000364.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000365.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000366.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000367.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000368.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000369.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000370.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000371.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000372.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000373.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000374.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000375.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000376.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000377.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000378.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000379.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000380.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000381.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000382.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000383.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000384.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000385.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000386.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000387.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000388.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000389.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000390.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000391.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000392.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000393.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000394.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000395.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000396.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000397.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000398.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000399.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000400.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000401.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000402.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000403.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000404.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000405.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000406.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000407.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000408.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000409.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000410.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000411.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000412.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000413.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000414.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000415.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000416.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000417.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000418.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000419.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000420.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000421.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000422.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000423.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000424.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000425.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000426.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000427.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000428.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000429.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000430.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000431.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000432.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000433.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000434.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000435.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000436.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000437.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000438.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000439.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000440.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000441.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000442.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000443.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000444.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000445.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000446.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000447.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000448.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000449.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000450.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000451.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000452.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000453.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000454.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000455.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000456.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000457.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000458.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000459.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000460.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000461.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000462.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000463.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000464.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000465.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000466.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000467.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000468.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000469.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000470.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000471.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000472.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000473.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000474.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000475.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000476.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000477.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000478.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000479.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000480.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000481.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000482.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000483.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000484.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000485.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000486.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000487.png
# ...
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000838.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000839.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000840.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000841.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000842.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000843.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000844.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000845.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000846.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000847.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000848.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000849.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000850.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000851.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000852.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000853.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000854.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000855.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000856.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000857.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000858.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000859.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000860.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000861.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000862.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000863.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000864.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000865.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000866.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000867.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000868.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000869.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000870.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000871.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000872.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000873.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000874.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000875.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000876.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000877.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000878.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000879.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000880.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000881.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000882.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000883.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000884.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000885.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000886.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000887.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000888.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000889.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000890.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000891.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000892.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000893.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000894.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000895.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000896.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000897.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000898.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000899.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000900.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000901.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000902.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000903.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000904.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000905.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000906.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000907.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000908.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000909.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000910.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000911.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000912.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000913.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000914.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000915.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000916.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000917.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000918.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000919.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000920.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000921.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000922.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000923.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000924.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000925.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000926.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000927.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000928.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000929.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000930.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000931.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000932.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000933.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000934.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000935.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000936.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000937.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000938.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000939.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000940.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000941.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000942.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000943.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000944.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000945.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000946.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000947.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000948.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000949.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000950.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000951.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000952.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000953.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000954.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000955.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000956.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000957.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000958.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000959.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000960.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000961.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000962.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000963.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000964.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000965.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000966.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000967.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000968.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000969.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000970.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000971.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000972.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000973.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000974.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000975.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000976.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000977.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000978.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000979.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000980.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000981.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000982.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000983.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000984.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000985.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000986.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000987.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000988.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000989.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000990.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000991.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000992.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000993.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000994.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000995.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000996.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000997.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000998.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/00000/img00000999.png
#  extracting: /content/drive/MyDrive/WIP/stylegan3/data/artimages_unzipped/dataset.json

# %% [markdown]
# # Model training

# %% [markdown]
# You can start from a pre-trained model. Below are some of the models from Nvdia
#
#
#
# ```
# stylegan3-t-ffhq-1024x1024.pkl, stylegan3-t-ffhqu-1024x1024.pkl, stylegan3-t-ffhqu-256x256.pkl
# stylegan3-r-ffhq-1024x1024.pkl, stylegan3-r-ffhqu-1024x1024.pkl, stylegan3-r-ffhqu-256x256.pkl
# stylegan3-t-metfaces-1024x1024.pkl, stylegan3-t-metfacesu-1024x1024.pkl
# stylegan3-r-metfaces-1024x1024.pkl, stylegan3-r-metfacesu-1024x1024.pkl
# stylegan3-t-afhqv2-512x512.pkl
# stylegan3-r-afhqv2-512x512.pkl
# ```

# %% [markdown]
# ## Using pre-trainined model

# %%
# Fine-tune StyleGAN3-R for MetFaces-U using 1 GPU, starting from the pre-trained FFHQ-U pickle.
# !python /content/drive/MyDrive/WIP/stylegan3/train.py --outdir=~/training-runs --cfg=stylegan3-r --data=/content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip \
    --gpus=1 --batch=32 --batch-gpu=16 --gamma=6.6 --mirror=1 --kimg=500 --snap=5 \
    --resume=https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 65536,
#     "channel_max": 1024,
#     "magnitude_ema_beta": 0.9988915792636801,
#     "conv_kernel": 1,
#     "use_radial_filters": true
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 6.6,
#     "blur_init_sigma": 0,
#     "blur_fade_kimg": 200.0
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 3
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip",
#     "use_labels": false,
#     "max_size": 1000,
#     "xflip": true,
#     "resolution": 512,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 32,
#   "batch_gpu": 16,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "total_kimg": 500,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 5,
#   "network_snapshot_ticks": 5,
#   "random_seed": 0,
#   "ema_kimg": 10.0,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "resume_pkl": "https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl",
#   "ada_kimg": 100,
#   "ema_rampup": null,
#   "run_dir": "~/training-runs/00000-stylegan3-r-art-painting-512x512-gpus1-batch32-gamma6.6"
# }
#
# Output directory:    ~/training-runs/00000-stylegan3-r-art-painting-512x512-gpus1-batch32-gamma6.6
# Number of GPUs:      1
# Batch size:          32 images
# Training duration:   500 kimg
# Dataset path:        /content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip
# Dataset size:        1000 images
# Dataset resolution:  512
# Dataset labels:      False
# Dataset x-flips:     True
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
# Num images:  2000
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl"
# Downloading https://api.ngc.nvidia.com/v2/models/nvidia/research/stylegan3/versions/1/files/stylegan3-r-ffhqu-1024x1024.pkl ... done
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 286, in <module>
#     main() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 281, in main
#     launch_training(c=c, desc=desc, outdir=opts.outdir, dry_run=opts.dry_run)
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 96, in launch_training
#     subprocess_fn(rank=0, c=c, temp_dir=temp_dir)
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 47, in subprocess_fn
#     training_loop.training_loop(rank=rank, **c)
#   File "/content/drive/MyDrive/WIP/stylegan3/training/training_loop.py", line 162, in training_loop
#     misc.copy_params_and_buffers(resume_data[name], module, require_all=False)
#   File "/content/drive/MyDrive/WIP/stylegan3/torch_utils/misc.py", line 162, in copy_params_and_buffers
#     tensor.copy_(src_tensors[name].detach()).requires_grad_(tensor.requires_grad)
# RuntimeError: The size of tensor a (24) must match the size of tensor b (12) at non-singleton dimension 0

# %% [markdown]
# ## Finetuning a model

# %%
batch_size = 16
batch_gpu_size = 8 # Batch size for GPU

dataset_path = '/content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip'
#resume_from = '/content/drive/MyDrive/WIP/stylegan3/models/stylegan3-t-afhqv2-512x512.pkl'  #Can be the link from nvidia
resume_from ='/content/drive/MyDrive/WIP/stylegan3/models/network-a657-r-512-148863.pkl'


gamma_value = 50.0 #Adjustable R1 regularization weight
snapshot_count = 8

# %%
# Fine-tune StyleGAN3-R for MetFaces-U using 1 GPU, starting from the pre-trained FFHQ-U pickle.
# !python /content/drive/MyDrive/WIP/stylegan3/train.py --outdir=/content/drive/MyDrive/WIP/stylegan3/results --cfg=stylegan3-t \
--data=$dataset_path --gpus=1 --batch=$batch_size --batch-gpu=$batch_gpu_size --gamma=$gamma_value --kimg=1 \
--snap=$snapshot_count --resume=$resume_from
# Out:
# Training options:
# {
#   "G_kwargs": {
#     "class_name": "training.networks_stylegan3.Generator",
#     "z_dim": 512,
#     "w_dim": 512,
#     "mapping_kwargs": {
#       "num_layers": 2
#     },
#     "channel_base": 32768,
#     "channel_max": 512,
#     "magnitude_ema_beta": 0.9994456359721023
#   },
#   "D_kwargs": {
#     "class_name": "training.networks_stylegan2.Discriminator",
#     "block_kwargs": {
#       "freeze_layers": 0
#     },
#     "mapping_kwargs": {},
#     "epilogue_kwargs": {
#       "mbstd_group_size": 4
#     },
#     "channel_base": 32768,
#     "channel_max": 512
#   },
#   "G_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.0025
#   },
#   "D_opt_kwargs": {
#     "class_name": "torch.optim.Adam",
#     "betas": [
#       0,
#       0.99
#     ],
#     "eps": 1e-08,
#     "lr": 0.002
#   },
#   "loss_kwargs": {
#     "class_name": "training.loss.StyleGAN2Loss",
#     "r1_gamma": 50.0,
#     "blur_init_sigma": 0
#   },
#   "data_loader_kwargs": {
#     "pin_memory": true,
#     "prefetch_factor": 2,
#     "num_workers": 3
#   },
#   "training_set_kwargs": {
#     "class_name": "training.dataset.ImageFolderDataset",
#     "path": "/content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip",
#     "use_labels": false,
#     "max_size": 1000,
#     "xflip": false,
#     "resolution": 512,
#     "random_seed": 0
#   },
#   "num_gpus": 1,
#   "batch_size": 16,
#   "batch_gpu": 8,
#   "metrics": [
#     "fid50k_full"
#   ],
#   "total_kimg": 1,
#   "kimg_per_tick": 4,
#   "image_snapshot_ticks": 8,
#   "network_snapshot_ticks": 8,
#   "random_seed": 0,
#   "ema_kimg": 5.0,
#   "augment_kwargs": {
#     "class_name": "training.augment.AugmentPipe",
#     "xflip": 1,
#     "rotate90": 1,
#     "xint": 1,
#     "scale": 1,
#     "rotate": 1,
#     "aniso": 1,
#     "xfrac": 1,
#     "brightness": 1,
#     "contrast": 1,
#     "lumaflip": 1,
#     "hue": 1,
#     "saturation": 1
#   },
#   "ada_target": 0.6,
#   "resume_pkl": "/content/drive/MyDrive/WIP/stylegan3/models/network-a657-r-512-148863.pkl",
#   "ada_kimg": 100,
#   "ema_rampup": null,
#   "run_dir": "/content/drive/MyDrive/WIP/stylegan3/results/00000-stylegan3-t-art-painting-512x512-gpus1-batch16-gamma50"
# }
#
# Output directory:    /content/drive/MyDrive/WIP/stylegan3/results/00000-stylegan3-t-art-painting-512x512-gpus1-batch16-gamma50
# Number of GPUs:      1
# Batch size:          16 images
# Training duration:   1 kimg
# Dataset path:        /content/drive/MyDrive/WIP/stylegan3/datasets/art-painting-512x512.zip
# Dataset size:        1000 images
# Dataset resolution:  512
# Dataset labels:      False
# Dataset x-flips:     False
#
# Creating output directory...
# Launching processes...
# Loading training set...
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/sampler.py:64: UserWarning: `data_source` argument is not used and will be removed in 2.2.0.You may still have custom implementation that utilizes it.
#   warnings.warn("`data_source` argument is not used and will be removed in 2.2.0."
# /usr/local/lib/python3.10/dist-packages/torch/utils/data/dataloader.py:558: UserWarning: This DataLoader will create 3 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   warnings.warn(_create_warning_msg(
#
# Num images:  1000
# Image shape: [3, 512, 512]
# Label shape: [0]
#
# Constructing networks...
# Resuming from "/content/drive/MyDrive/WIP/stylegan3/models/network-a657-r-512-148863.pkl"
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 286, in <module>
#     main() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 281, in main
#     launch_training(c=c, desc=desc, outdir=opts.outdir, dry_run=opts.dry_run)
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 96, in launch_training
#     subprocess_fn(rank=0, c=c, temp_dir=temp_dir)
#   File "/content/drive/MyDrive/WIP/stylegan3/train.py", line 47, in subprocess_fn
#     training_loop.training_loop(rank=rank, **c)
#   File "/content/drive/MyDrive/WIP/stylegan3/training/training_loop.py", line 159, in training_loop
#     with dnnlib.util.open_url(resume_pkl) as f:
#   File "/content/drive/MyDrive/WIP/stylegan3/dnnlib/util.py", line 403, in open_url
#     return url if return_filename else open(url, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/WIP/stylegan3/models/network-a657-r-512-148863.pkl'
# Exception ignored in atexit callback: <function _exit_function at 0x79eb15efe830>
# Traceback (most recent call last):
#   File "/usr/lib/python3.10/multiprocessing/util.py", line 357, in _exit_function
#     p.join()
#   File "/usr/lib/python3.10/multiprocessing/process.py", line 149, in join
#     res = self._popen.wait(timeout)
#   File "/usr/lib/python3.10/multiprocessing/popen_fork.py", line 43, in wait
#     return self.poll(os.WNOHANG if timeout == 0.0 else 0)
#   File "/usr/lib/python3.10/multiprocessing/popen_fork.py", line 27, in poll
#     pid, sts = os.waitpid(self.pid, flag)
#   File "/usr/local/lib/python3.10/dist-packages/torch/utils/data/_utils/signal_handling.py", line 66, in handler
#     _error_if_any_worker_fails()
# RuntimeError: DataLoader worker (pid 22622) is killed by signal: Terminated.

# %%
#Visualization - does not work on colab
#!python /content/drive/MyDrive/WIP/stylegan3/visualizer.py

# %% [markdown]
# # Generate images

# %%
model_path = '/content/drive/MyDrive/WIP/stylegan3/results/00002-stylegan3-t-artimages-512x512-gpus1-batch16-gamma50/network-snapshot-000001.pkl'

# %%
#Random generation of images using model created

# !python /content/drive/MyDrive/WIP/stylegan3/gen_images.py --outdir=out --trunc=1 --seeds=40 \
    --network=$model_path
# Out:
# Loading networks from "/content/drive/MyDrive/WIP/stylegan3/results/00002-stylegan3-t-artimages-512x512-gpus1-batch16-gamma50/network-snapshot-000001.pkl"...
# Traceback (most recent call last):
#   File "/content/drive/MyDrive/WIP/stylegan3/gen_images.py", line 143, in <module>
#     generate_images() # pylint: disable=no-value-for-parameter
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1157, in __call__
#     return self.main(*args, **kwargs)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1078, in main
#     rv = self.invoke(ctx)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 1434, in invoke
#     return ctx.invoke(self.callback, **ctx.params)
#   File "/usr/local/lib/python3.10/dist-packages/click/core.py", line 783, in invoke
#     return __callback(*args, **kwargs)
#   File "/content/drive/MyDrive/WIP/stylegan3/gen_images.py", line 107, in generate_images
#     with dnnlib.util.open_url(network_pkl) as f:
#   File "/content/drive/MyDrive/WIP/stylegan3/dnnlib/util.py", line 403, in open_url
#     return url if return_filename else open(url, "rb")
# FileNotFoundError: [Errno 2] No such file or directory: '/content/drive/MyDrive/WIP/stylegan3/results/00002-stylegan3-t-artimages-512x512-gpus1-batch16-gamma50/network-snapshot-000001.pkl'

# %% [markdown]
# Check-out other articles [Medium](https://bvshyam.medium.com/)
